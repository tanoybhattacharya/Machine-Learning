# %%
import numpy as np
import pandas as pd 

# Load the dataset
data = pd.read_csv("OnlineNewsPopularity.csv")
data.head()
# Out:
#                                                  url  timedelta  \
# 0  http://mashable.com/2013/01/07/amazon-instant-...      731.0
# 1  http://mashable.com/2013/01/07/ap-samsung-spon...      731.0
# 2  http://mashable.com/2013/01/07/apple-40-billio...      731.0
# 3  http://mashable.com/2013/01/07/astronaut-notre...      731.0
# 4   http://mashable.com/2013/01/07/att-u-verse-apps/      731.0
#
#    n_tokens_title  n_tokens_content  n_unique_tokens  n_non_stop_words  \
# 0            12.0             219.0         0.663594               1.0
# 1             9.0             255.0         0.604743               1.0
# 2             9.0             211.0         0.575130               1.0
# 3             9.0             531.0         0.503788               1.0
# 4            13.0            1072.0         0.415646               1.0
#
#    n_non_stop_unique_tokens  num_hrefs  num_self_hrefs  num_imgs  ...  \
# 0                  0.815385        4.0             2.0       1.0  ...
# ...

# %%
# The statistics of original target 
popularity_raw = data[data.keys()[-1]]
popularity_raw.describe()
# Out:
# count     39644.000000
# mean       3395.380184
# std       11626.950749
# min           1.000000
# 25%         946.000000
# 50%        1400.000000
# 75%        2800.000000
# max      843300.000000
# Name: shares, dtype: float64

# %% [markdown]
# __Encode the label by threshold 1400 Beacause majority 50% stock price over 1400 as per statistic__

# %%
from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder()
popular_label = pd.Series(label_encoder.fit_transform(popularity_raw>=1400))

# %%
# Features from dataset
features_raw = data.drop(['url',data.keys()[1],data.keys()[-1]], axis=1)
features_raw.head()
# Out:
#    n_tokens_title  n_tokens_content  n_unique_tokens  n_non_stop_words  \
# 0            12.0             219.0         0.663594               1.0
# 1             9.0             255.0         0.604743               1.0
# 2             9.0             211.0         0.575130               1.0
# 3             9.0             531.0         0.503788               1.0
# 4            13.0            1072.0         0.415646               1.0
#
#    n_non_stop_unique_tokens  num_hrefs  num_self_hrefs  num_imgs  num_videos  \
# 0                  0.815385        4.0             2.0       1.0         0.0
# 1                  0.791946        3.0             1.0       1.0         0.0
# 2                  0.663866        3.0             1.0       1.0         0.0
# 3                  0.665635        9.0             0.0       1.0         0.0
# 4                  0.540890       19.0            19.0      20.0         0.0
#
# ...

# %%
#Get the statistic for all The Feature
features_raw.describe()
# Out:
#        n_tokens_title  n_tokens_content  n_unique_tokens  n_non_stop_words  \
# count    39644.000000      39644.000000     39644.000000      39644.000000
# mean        10.398749        546.514731         0.548216          0.996469
# std          2.114037        471.107508         3.520708          5.231231
# min          2.000000          0.000000         0.000000          0.000000
# 25%          9.000000        246.000000         0.470870          1.000000
# 50%         10.000000        409.000000         0.539226          1.000000
# 75%         12.000000        716.000000         0.608696          1.000000
# max         23.000000       8474.000000       701.000000       1042.000000
#
#        n_non_stop_unique_tokens     num_hrefs  num_self_hrefs      num_imgs  \
# count              39644.000000  39644.000000    39644.000000  39644.000000
# mean                   0.689175     10.883690        3.293638      4.544143
# ...

# %% [markdown]
# __Need data normalization for all the numeric feature__

# %%
# Normalize the numerical features
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
numerical = ['n_tokens_title', 'n_tokens_content', 'num_hrefs', 'num_self_hrefs', 'num_imgs','num_videos','average_token_length','num_keywords','self_reference_min_shares','self_reference_max_shares','self_reference_avg_sharess']
features_raw[numerical] = scaler.fit_transform(data[numerical])
features_raw.head()
# Out:
#    n_tokens_title  n_tokens_content  n_unique_tokens  n_non_stop_words  \
# 0        0.476190          0.025844         0.663594               1.0
# 1        0.333333          0.030092         0.604743               1.0
# 2        0.333333          0.024900         0.575130               1.0
# 3        0.333333          0.062662         0.503788               1.0
# 4        0.523810          0.126505         0.415646               1.0
#
#    n_non_stop_unique_tokens  num_hrefs  num_self_hrefs  num_imgs  num_videos  \
# 0                  0.815385   0.013158        0.017241  0.007812         0.0
# 1                  0.791946   0.009868        0.008621  0.007812         0.0
# 2                  0.663866   0.009868        0.008621  0.007812         0.0
# 3                  0.665635   0.029605        0.000000  0.007812         0.0
# 4                  0.540890   0.062500        0.163793  0.156250         0.0
#
# ...

# %%
features_raw.describe()
# Out:
#        n_tokens_title  n_tokens_content  n_unique_tokens  n_non_stop_words  \
# count    39644.000000      39644.000000     39644.000000      39644.000000
# mean         0.399940          0.064493         0.548216          0.996469
# std          0.100668          0.055594         3.520708          5.231231
# min          0.000000          0.000000         0.000000          0.000000
# 25%          0.333333          0.029030         0.470870          1.000000
# 50%          0.380952          0.048265         0.539226          1.000000
# 75%          0.476190          0.084494         0.608696          1.000000
# max          1.000000          1.000000       701.000000       1042.000000
#
#        n_non_stop_unique_tokens     num_hrefs  num_self_hrefs      num_imgs  \
# count              39644.000000  39644.000000    39644.000000  39644.000000
# mean                   0.689175      0.035802        0.028393      0.035501
# ...

# %% [markdown]
# __Now all feature attribute is now normalized with evidence of std__

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(features_raw,popular_label,test_size=0.2,random_state=2)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier,VotingClassifier,AdaBoostClassifier
from sklearn.metrics import accuracy_score
from xgboost import XGBClassifier

# %%
lg = LogisticRegression()
rf = RandomForestClassifier()
ad = AdaBoostClassifier(n_estimators=50,learning_rate=1)
xg = XGBClassifier()

# %%
# Accuray of Logistic regrassion
accuracy_score(lg.fit(X_train,y_train).predict(X_test),y_test)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# 0.6044898473956363

# %%
# Accuray of RandomSeacrh
accuracy_score(rf.fit(X_train,y_train).predict(X_test),y_test)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# 0.6283263967713457

# %%
# Accuray of Adaboost
accuracy_score(ad.fit(X_train,y_train).predict(X_test),y_test)
# Out:
# 0.6598562239878926

# %%
# Accuray of XGBoost
accuracy_score(xg.fit(X_train,y_train).predict(X_test),y_test)
# Out:
# 0.6693151721528566

# %%
# Accuray of VootingClassifier
vt = VotingClassifier(estimators = [('lg', lg),('rf', rf),('ad', ad),('xg',xg)],
                                       voting = 'hard')
accuracy_score(vt.fit(X_train,y_train).predict(X_test),y_test)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# 0.6611174170765545

# %%
from sklearn.model_selection import cross_val_score
scores=cross_val_score(vt, features_raw,popular_label, cv=5)
scores
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# ...

# %%
np.mean(scores)
# Out:
# 0.6326559733782628
